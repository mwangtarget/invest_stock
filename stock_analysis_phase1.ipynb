# %%
import tushare as ts
import datetime
import sqlite3

if __name__ == '__main__':
    ts.set_token("73d044da8e0d5f08c5fe7050c8ea28a1cb9c72d4c88fb5e9c35fba60")
    pro = ts.pro_api()
    df_shibor = pro.shibor(start_date='20090501', end_date="20090630")
    print(df_shibor)
# Out:
#         date      on      1w      2w      1m      3m      6m      9m      1y
# 0   20090630  1.0900  1.2117  1.2533  1.3008  1.3179  1.4977  1.6605  1.8688
# 1   20090629  1.0000  1.1900  1.2108  1.2808  1.3068  1.4961  1.6576  1.8678
# 2   20090626  0.9621  1.1717  1.2221  1.2717  1.2978  1.4957  1.6563  1.8672
# 3   20090625  0.9588  1.1288  1.2233  1.2555  1.2925  1.4953  1.6562  1.8666
# 4   20090624  0.9575  1.1850  1.2202  1.2450  1.2908  1.4948  1.6547  1.8663
# 5   20090623  0.9579  1.1000  1.2113  1.2142  1.2825  1.4904  1.6534  1.8655
# 6   20090622  0.9479  1.0892  1.1725  1.1883  1.2748  1.4892  1.6521  1.8639
# 7   20090619  0.9025  0.9967  1.0975  1.1088  1.2580  1.4815  1.6475  1.8602
# 8   20090618  0.8450  0.9525  0.9850  1.0409  1.2371  1.4747  1.6400  1.8544
# 9   20090617  0.8304  0.9425  0.9592  1.0380  1.2345  1.4728  1.6399  1.8534
# 10  20090616  0.8171  0.9421  0.9630  1.0334  1.2341  1.4731  1.6398  1.8534
# ...

# %%
df_shibor = pro.shibor(start_date='20200101', end_date="20200405")
print(df_shibor)
# Out:
#         date      on     1w     2w      1m     3m     6m     9m     1y
# 0   20200403  1.0010  1.831  1.537  1.7410  1.844  1.956  2.075  2.165
# 1   20200402  1.2780  1.857  1.621  1.7720  1.889  1.982  2.098  2.202
# 2   20200401  1.4030  2.004  1.736  1.8090  1.918  2.015  2.123  2.226
# 3   20200331  1.6140  2.147  1.854  1.8270  1.933  2.033  2.140  2.250
# 4   20200330  1.3740  2.163  1.786  1.8350  1.948  2.051  2.159  2.274
# ..       ...     ...    ...    ...     ...    ...    ...    ...    ...
# 57  20200108  1.5530  2.320  2.160  2.6380  2.881  2.930  2.983  3.032
# 58  20200107  1.2150  2.259  2.176  2.7000  2.899  2.943  2.992  3.040
# 59  20200106  1.0030  2.219  2.091  2.7470  2.920  2.960  3.005  3.050
# 60  20200103  1.1620  2.349  2.190  2.8420  2.960  2.995  3.028  3.071
# 61  20200102  1.4436  2.433  2.334  2.8975  2.994  3.019  3.052  3.086
#
# [62 rows x 9 columns]

# %%
df_shibor = pro.shibor(start_date='20191101', end_date="20191205")
print(df_shibor)
# Out:
#         date     on     1w     2w      1m     3m     6m     9m     1y
# 0   20191205  1.906  2.433  2.317  2.8110  3.022  3.050  3.073  3.121
# 1   20191204  1.971  2.426  2.350  2.7990  3.019  3.050  3.072  3.121
# 2   20191203  2.132  2.343  2.361  2.7850  3.015  3.050  3.071  3.122
# 3   20191202  2.233  2.478  2.451  2.7790  3.017  3.050  3.071  3.122
# 4   20191129  2.356  2.607  2.540  2.7830  3.017  3.050  3.070  3.122
# 5   20191128  2.078  2.597  2.594  2.7795  3.016  3.050  3.069  3.119
# 6   20191127  2.233  2.589  2.599  2.7815  3.019  3.050  3.067  3.119
# 7   20191126  2.323  2.598  2.600  2.7835  3.020  3.047  3.067  3.118
# 8   20191125  2.234  2.596  2.639  2.7875  3.029  3.050  3.066  3.119
# 9   20191122  1.948  2.536  2.500  2.7925  3.037  3.050  3.067  3.121
# 10  20191121  1.849  2.426  2.489  2.7945  3.034  3.050  3.070  3.127
# 11  20191120  1.899  2.497  2.570  2.7950  3.032  3.051  3.071  3.125
# ...

# %%
df_shibor = pro.shibor(start_date='20191101', end_date="20200405")

# %%
on_df = df_shibor[["date", "on"]]

# %%
on_df.head()
# Out:
#        date     on
# 0  20200403  1.001
# 1  20200402  1.278
# 2  20200401  1.403
# 3  20200331  1.614
# 4  20200330  1.374

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-033ff7115bce> in <module>
# ----> 1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 import matplotlib.pyplot as plt
#
# ~/trading/invest_stock/venv/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2315                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2316             with self.builtin_trap:
# -> 2317                 result = fn(*args, **kwargs)
#    2318             return result
#    2319
#
# <decorator-gen-108> in matplotlib(self, line)
#
# ~/trading/invest_stock/venv/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot(on_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-55d4dcc19a1d> in <module>
# ----> 1 plt.plot(on_df)
#
# ~/trading/invest_stock/venv/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2759 @docstring.copy(Axes.plot)
#    2760 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
#    2763         is not None else {}), **kwargs)
#
# ~/trading/invest_stock/venv/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1644         """
#    1645         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1646         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1647         for line in lines:
# ...

# %%
on_df.plot()

# %%
on_df.header
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-28804e4b5a10> in <module>
# ----> 1 on_df.header
#
# ~/trading/invest_stock/venv/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'header'

# %%
on_df.columns
# Out:
# Index(['date', 'on'], dtype='object')

# %%
on_df.plot(x='date', y='on')

# %%
on_df.rolling(30)
# Out:
# Rolling [window=30,center=False,axis=0]

# %%
on_df.rolling(30).average()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-cf69abcf7b1d> in <module>
# ----> 1 on_df.rolling(30).average()
#
# ~/trading/invest_stock/venv/lib/python3.8/site-packages/pandas/core/window/rolling.py in __getattr__(self, attr)
#     190             return self[attr]
#     191
# --> 192         raise AttributeError(
#     193             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     194         )
#
# AttributeError: 'Rolling' object has no attribute 'average'

# %%
on_df.rolling(30).mean()
# Out:
#              date        on
# 0             NaN       NaN
# 1             NaN       NaN
# 2             NaN       NaN
# 3             NaN       NaN
# 4             NaN       NaN
# ..            ...       ...
# 100  2.019116e+07  2.223533
# 101  2.019115e+07  2.200300
# 102  2.019115e+07  2.179433
# 103  2.019115e+07  2.167367
# 104  2.019114e+07  2.172967
#
# [105 rows x 2 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-611fc9d45b5d> in <module>
#      18 fenshi_initial_table={}  #原始单日所有成交单
#      19 for i in date_table():
# ---> 20     (fenshi_initial_table[i],chouma_initial_table[i])=chouma_initial_day(i)
#      21 chouma={}
#      22 for i in date_table():  #迭代出  不同日期的   筹码分价表，以字典形式存储
#
# <ipython-input-17-611fc9d45b5d> in chouma_initial_day(date_str)
#       9
#      10 def chouma_initial_day(date_str):  #定义原始的筹码数据表
# ---> 11     date_str=date_str_(date_str)
#      12     #print(date_str)
#      13     df = ts.get_tick_data(gegu_code,date=date_str,src='tt')  #使用get_tick_data接口，调取一天的所有交易
#
# NameError: name 'date_str_' is not defined

# %%
pring(tu.__version__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-8beca27cecc2> in <module>
# ----> 1 pring(tu.__version__)
#
# NameError: name 'pring' is not defined

# %%
print(tu.__version__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-559da10b1e19> in <module>
# ----> 1 print(tu.__version__)
#
# NameError: name 'tu' is not defined

# %%
import tushare as ts
import datetime
import sqlite3

print(ts.__version__)
# Out:
# 1.2.54

# %%
pro = ts.pro_api()

#查询当前所有正常上市交易的股票列表

data = pro.stock_basic(exchange='', list_status='L', fields='ts_code,symbol,name,area,industry,list_date')

# %%
print data
# Out:
#   File "<ipython-input-22-d5bd85cc9860>", line 1
#     print data
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(data)?

# %%
print(data)
# Out:
#         ts_code  symbol  name area industry list_date
# 0     000001.SZ  000001  平安银行   深圳       银行  19910403
# 1     000002.SZ  000002   万科A   深圳     全国地产  19910129
# 2     000004.SZ  000004  国农科技   深圳     生物制药  19910114
# 3     000005.SZ  000005  世纪星源   深圳     环境保护  19901210
# 4     000006.SZ  000006  深振业A   深圳     区域地产  19920427
# ...         ...     ...   ...  ...      ...       ...
# 3797  688388.SH  688388  嘉元科技   广东      元器件  20190722
# 3798  688389.SH  688389  普门科技   深圳     医疗保健  20191105
# 3799  688396.SH  688396   华润微   江苏      元器件  20200227
# 3800  688398.SH  688398  赛特新材   福建     矿物制品  20200211
# 3801  688399.SH  688399  硕世生物   江苏     医疗保健  20191205
#
# [3802 rows x 6 columns]

# %%
pro = ts.pro_api()

#查询当前所有正常上市交易的股票列表

data = pro.stock_basic(exchange='SZ', list_status='L', fields='ts_code,symbol,name,area,industry,list_date')

# %%
data
# Out:
# Empty DataFrame
# Columns: [ts_code, symbol, name, area, industry, list_date]
# Index: []

# %%
print(data)
# Out:
# Empty DataFrame
# Columns: [ts_code, symbol, name, area, industry, list_date]
# Index: []

# %%
data = pro.stock_basic(exchange='SZSE', list_status='L')
print(data)
# Out:
#         ts_code  symbol  name area industry market list_date
# 0     000001.SZ  000001  平安银行   深圳       银行     主板  19910403
# 1     000002.SZ  000002   万科A   深圳     全国地产     主板  19910129
# 2     000004.SZ  000004  国农科技   深圳     生物制药     主板  19910114
# 3     000005.SZ  000005  世纪星源   深圳     环境保护     主板  19901210
# 4     000006.SZ  000006  深振业A   深圳     区域地产     主板  19920427
# ...         ...     ...   ...  ...      ...    ...       ...
# 2200  300821.SZ  300821  东岳硅材   山东     化工原料    创业板  20200312
# 2201  300822.SZ  300822  贝仕达克   深圳      元器件    创业板  20200313
# 2202  300823.SZ  300823  建科机械   天津     专用机械    创业板  20200319
# 2203  300825.SZ  300825   阿尔特   北京     汽车服务    创业板  20200327
# 2204  300826.SZ  300826   N测绘   江苏     建筑工程    创业板  20200403
#
# [2205 rows x 7 columns]

# %%
data['area' == '天津']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/trading/invest_stock/venv/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-625c5c08dbca> in <module>
# ----> 1 data['area' == '天津']
#
# ...

# %%
data[data['area']=='天津']
# Out:
#         ts_code  symbol   name area industry market list_date
# 126   000537.SZ  000537   广宇发展   天津     区域地产     主板  19931210
# 210   000652.SZ  000652   泰达股份   天津      批发业     主板  19961128
# 242   000695.SZ  000695   滨海能源   天津     广告包装     主板  19970218
# 341   000836.SZ  000836   富通鑫茂   天津     通信设备     主板  19970929
# 375   000897.SZ  000897  *ST津滨   天津     区域地产     主板  19990422
# 400   000927.SZ  000927   一汽夏利   天津     汽车整车     主板  19990727
# 425   000965.SZ  000965   天保基建   天津     区域地产     主板  20000406
# 456   001965.SZ  001965   招商公路   天津       路桥     主板  20171225
# 584   002129.SZ  002129   中环股份   天津      半导体    中小板  20070420
# 589   002134.SZ  002134   天津普林   天津      元器件    中小板  20070516
# 789   002337.SZ  002337   赛象科技   天津     化工机械    中小板  20100115
# 845   002393.SZ  002393   力生制药   天津     化学制药    中小板  20100423
# 884   002432.SZ  002432   九安医疗   天津     医疗保健    中小板  20100610
# 961   002510.SZ  002510    天汽模   天津     汽车配件    中小板  20101125
# ...

# %%
data_sh = pro.stock_basic(exchange='SSE', list_status='L')
data_sh_tj=data_sh[data_sh['area']=='天津']
print(data_sh_tj)
# Out:
#         ts_code  symbol  name area industry market list_date
# 62    600082.SH  600082  海泰发展   天津     园区开发     主板  19970620
# 128   600158.SH  600158  中体产业   天津     文教休闲     主板  19980327
# 187   600225.SH  600225  天津松江   天津     区域地产     主板  20000127
# 270   600322.SH  600322  天房发展   天津     区域地产     主板  20010910
# 276   600329.SH  600329  中新药业   天津      中成药     主板  20010606
# 281   600335.SH  600335  国机汽车   天津     汽车配件     主板  20010305
# 375   600468.SH  600468  百利电气   天津     电气设备     主板  20010615
# 390   600488.SH  600488  天药股份   天津     化学制药     主板  20010618
# 431   600535.SH  600535   天士力   天津      中成药     主板  20020823
# 472   600583.SH  600583  海油工程   天津     石油开采     主板  20020205
# 527   600645.SH  600645  中源协和   天津     生物制药     主板  19930504
# 590   600717.SH  600717   天津港   天津       港口     主板  19960614
# 623   600751.SH  600751  海航科技   天津       水运     主板  19960909
# 655   600787.SH  600787  中储股份   天津     仓储物流     主板  19970121
# ...

# %%
data_sh = pro.stock_basic(exchange='SSE', list_status='L')
data_sh_js=data_sh[data_sh['area']=='江苏']
print(data_sh_js)
# Out:
#         ts_code  symbol  name area industry market list_date
# 46    600064.SH  600064  南京高科   江苏     园区开发     主板  19970506
# 58    600078.SH  600078  澄星股份   江苏     化工原料     主板  19970627
# 63    600083.SH  600083  博信股份   江苏      综合类     主板  19970606
# 77    600099.SH  600099  林海股份   江苏      摩托车     主板  19970704
# 82    600105.SH  600105  永鼎股份   江苏     通信设备     主板  19970929
# ...         ...     ...   ...  ...      ...    ...       ...
# 1576  688266.SH  688266  泽璟制药   江苏     化学制药    科创板  20200123
# 1582  688300.SH  688300  联瑞新材   江苏     矿物制品    科创板  20191115
# 1587  688358.SH  688358  祥生医疗   江苏     医疗保健    科创板  20191203
# 1594  688396.SH  688396   华润微   江苏      元器件    科创板  20200227
# 1596  688399.SH  688399  硕世生物   江苏     医疗保健    科创板  20191205
#
# [198 rows x 7 columns]

# %%
data_sh_js.count()
# Out:
# ts_code      198
# symbol       198
# name         198
# area         198
# industry     198
# market       198
# list_date    198
# dtype: int64

# %%
data_sh_tj.count()
# Out:
# ts_code      29
# symbol       29
# name         29
# area         29
# industry     29
# market       29
# list_date    29
# dtype: int64

# %%
data_sh = pro.stock_basic(exchange='SSE', list_status='L')
data_sh_sd=data_sh[data_sh['area']=='山东']
print(data_sh_sd)
# Out:
#         ts_code  symbol  name area industry market list_date
# 11    600017.SH  600017   日照港   山东       港口     主板  20061017
# 16    600022.SH  600022  山东钢铁   山东       普钢     主板  20040629
# 20    600027.SH  600027  华电国际   山东     火力发电     主板  20050203
# 42    600060.SH  600060  海信视像   山东     家用电器     主板  19970422
# 56    600076.SH  600076  康欣新材   山东     其他建材     主板  19970526
# ...         ...     ...   ...  ...      ...    ...       ...
# 1478  603967.SH  603967  中创物流   山东     仓储物流     主板  20190429
# 1504  688002.SH  688002  睿创微纳   山东     通信设备    科创板  20190722
# 1519  688021.SH  688021  奥福环保   山东     环境保护    科创板  20191106
# 1554  688139.SH  688139  海尔生物   山东     医疗保健    科创板  20191025
# 1588  688363.SH  688363  华熙生物   山东     生物制药    科创板  20191106
#
# [80 rows x 7 columns]

# %%
data_sh_sd.count()
# Out:
# ts_code      80
# symbol       80
# name         80
# area         80
# industry     80
# market       80
# list_date    80
# dtype: int64

# %%
data_sh = pro.stock_basic(exchange='SSE', list_status='L')
area_stock = data_sh.groupby('area')

# %%
area_stock.get_group('广东')
# Out:
#         ts_code  symbol  name area industry market list_date
# 1     600004.SH  600004  白云机场   广东       机场     主板  20030428
# 22    600029.SH  600029  南方航空   广东       空运     主板  20030725
# 31    600048.SH  600048  保利地产   广东     全国地产     主板  20060731
# 76    600098.SH  600098  广州发展   广东     火力发电     主板  19970718
# 116   600143.SH  600143  金发科技   广东       塑料     主板  20040623
# ...         ...     ...   ...  ...      ...    ...       ...
# 1552  688128.SH  688128  中国电研   广东     专用机械    科创板  20191105
# 1560  688177.SH  688177   百奥泰   广东     生物制药    科创板  20200221
# 1573  688228.SH  688228   开普云   广东      互联网    科创板  20200327
# 1577  688268.SH  688268  华特气体   广东     化工原料    科创板  20191226
# 1592  688388.SH  688388  嘉元科技   广东      元器件    科创板  20190722
#
# [72 rows x 7 columns]

# %%
import matplotlib as plt

# %%
area_stock.agg('count')
# Out:
#       ts_code  symbol  name  industry  market  list_date
# area
# 上海        223     223   223       223     223        223
# 云南         14      14    14        14      14         14
# 内蒙         15      15    15        15      15         15
# 北京        165     165   165       165     165        165
# 吉林         18      18    18        18      18         18
# 四川         43      43    43        43      43         43
# 天津         29      29    29        29      29         29
# 宁夏          6       6     6         6       6          6
# 安徽         48      48    48        48      48         48
# 山东         80      80    80        80      80         80
# 山西         19      19    19        19      19         19
# 广东         72      72    72        72      72         72
# 广西         17      17    17        17      17         17
# 新疆         29      29    29        29      29         29
# 江苏        198     198   198       198     198        198
# ...

# %%
area_stock.agg('count').sort
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-bce92e07b8b5> in <module>
# ----> 1 area_stock.agg('count').sort
#
# ~/trading/invest_stock/venv/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
area_stock.agg('count').sort_values(by='ts_code')
# Out:
#       ts_code  symbol  name  industry  market  list_date
# area
# 宁夏          6       6     6         6       6          6
# 青海          8       8     8         8       8          8
# 西藏          9       9     9         9       9          9
# 海南         11      11    11        11      11         11
# 云南         14      14    14        14      14         14
# 贵州         14      14    14        14      14         14
# 内蒙         15      15    15        15      15         15
# 甘肃         16      16    16        16      16         16
# 江西         17      17    17        17      17         17
# 广西         17      17    17        17      17         17
# 吉林         18      18    18        18      18         18
# 山西         19      19    19        19      19         19
# 河北         22      22    22        22      22         22
# 陕西         25      25    25        25      25         25
# 黑龙江        27      27    27        27      27         27
# ...

# %%
pro = ts.pro_api()

df = pro.income(ts_code='600000.SH', start_date='20180101', end_date='20180730', fields='ts_code,ann_date,f_ann_date,end_date,report_type,comp_type,basic_eps,diluted_eps')

# %%
print(df)
# Out:
#      ts_code  ann_date f_ann_date  end_date report_type comp_type  basic_eps  \
# 0  600000.SH  20180428   20180428  20180331           1         2       0.46
# 1  600000.SH  20180428   20180428  20171231           1         2       1.84
#
#    diluted_eps
# 0         0.46
# 1         1.84

# %%
data_sh_tj
# Out:
#         ts_code  symbol  name area industry market list_date
# 62    600082.SH  600082  海泰发展   天津     园区开发     主板  19970620
# 128   600158.SH  600158  中体产业   天津     文教休闲     主板  19980327
# 187   600225.SH  600225  天津松江   天津     区域地产     主板  20000127
# 270   600322.SH  600322  天房发展   天津     区域地产     主板  20010910
# 276   600329.SH  600329  中新药业   天津      中成药     主板  20010606
# 281   600335.SH  600335  国机汽车   天津     汽车配件     主板  20010305
# 375   600468.SH  600468  百利电气   天津     电气设备     主板  20010615
# 390   600488.SH  600488  天药股份   天津     化学制药     主板  20010618
# 431   600535.SH  600535   天士力   天津      中成药     主板  20020823
# 472   600583.SH  600583  海油工程   天津     石油开采     主板  20020205
# 527   600645.SH  600645  中源协和   天津     生物制药     主板  19930504
# 590   600717.SH  600717   天津港   天津       港口     主板  19960614
# 623   600751.SH  600751  海航科技   天津       水运     主板  19960909
# 655   600787.SH  600787  中储股份   天津     仓储物流     主板  19970121
# ...

# %%
for ts in data_sh_tj['ts_code']:
    print ts
# Out:
#   File "<ipython-input-45-3b09e3ee7730>", line 2
#     print ts
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(ts)?

# %%
for ts in data_sh_tj['ts_code']:
    print(ts)
# Out:
# 600082.SH
# 600158.SH
# 600225.SH
# 600322.SH
# 600329.SH
# 600335.SH
# 600468.SH
# 600488.SH
# 600535.SH
# 600583.SH
# 600645.SH
# 600717.SH
# 600751.SH
# 600787.SH
# 600800.SH
# 600821.SH
# 600874.SH
# 601360.SH
# 601808.SH
# 601919.SH
# 603019.SH
# 603096.SH
# 603106.SH
# 603126.SH
# 603712.SH
# 603727.SH
# 603969.SH
# 688108.SH
# 688199.SH

# %%
tj_income = pd.DataFrame(columns=['ts_code','ann_date','f_ann_date','end_date','report_type','comp_type','basic_eps'])
for ts in data_sh_tj['ts_code']:
    ts_income = pro.income(ts_code=ts, start_date='20180101', end_date='20180730', fields='ts_code,ann_date,f_ann_date,end_date,report_type,comp_type,basic_eps')
    tj_income.append(ts_income)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-5cadcfdd3cce> in <module>
# ----> 1 tj_income = pd.DataFrame(columns=['ts_code','ann_date','f_ann_date','end_date','report_type','comp_type','basic_eps'])
#       2 for ts in data_sh_tj['ts_code']:
#       3     ts_income = pro.income(ts_code=ts, start_date='20180101', end_date='20180730', fields='ts_code,ann_date,f_ann_date,end_date,report_type,comp_type,basic_eps')
#       4     tj_income.append(ts_income)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
tj_income = pd.DataFrame(columns=['ts_code','ann_date','f_ann_date','end_date','report_type','comp_type','basic_eps'])
for ts in data_sh_tj['ts_code']:
    ts_income = pro.income(ts_code=ts, start_date='20180101', end_date='20180730', fields='ts_code,ann_date,f_ann_date,end_date,report_type,comp_type,basic_eps')
    print(ts_income)
# Out:
#      ts_code  ann_date f_ann_date  end_date report_type comp_type  basic_eps
# 0  600082.SH  20180426   20180426  20180331           1         1     0.0128
# 1  600082.SH  20180426   20180426  20171231           1         1     0.0221
#      ts_code  ann_date f_ann_date  end_date report_type comp_type  basic_eps
# 0  600158.SH  20180428   20180428  20180331           1         1    -0.0126
# 1  600158.SH  20180327   20180327  20171231           1         1     0.0689
#      ts_code  ann_date f_ann_date  end_date report_type comp_type  basic_eps
# 0  600225.SH  20180425   20180425  20180331           1         1      -0.17
# 1  600225.SH  20180425   20180425  20171231           1         1       0.21
#      ts_code  ann_date f_ann_date  end_date report_type comp_type  basic_eps
# 0  600322.SH  20180425   20180425  20180331           1         1     0.0677
# 1  600322.SH  20180320   20180320  20171231           1         1     0.1973
# ...

# %%
print(tj_income)
# Out:
# Empty DataFrame
# Columns: [ts_code, ann_date, f_ann_date, end_date, report_type, comp_type, basic_eps]
# Index: []

# %%
tj_income = pd.DataFrame(columns=['ts_code','ann_date','f_ann_date','end_date','report_type','comp_type','basic_eps'])
for ts in data_sh_tj['ts_code']:
    ts_income = pro.income(ts_code=ts, start_date='20190101', end_date='20190730', fields='ts_code,ann_date,f_ann_date,end_date,report_type,comp_type,basic_eps')
    tj_income.append(ts_income)

# %%
tj_income = pd.DataFrame(columns=['ts_code','ann_date','f_ann_date','end_date','report_type','comp_type','basic_eps'])
for ts in data_sh_tj['ts_code']:
    ts_income = pro.income(ts_code=ts, start_date='20190901', end_date='20191231', fields='ts_code,ann_date,f_ann_date,end_date,report_type,comp_type,basic_eps')
    print(ts_income)
# Out:
#      ts_code  ann_date f_ann_date  end_date report_type comp_type  basic_eps
# 0  600082.SH  20191030   20191030  20190930           1         1     0.0264
# 1  600082.SH  20191030   20191030  20190930           1         1     0.0264
#      ts_code  ann_date f_ann_date  end_date report_type comp_type  basic_eps
# 0  600158.SH  20191031   20191031  20190930           1         1     0.0388
# 1  600158.SH  20191031   20191031  20190930           1         1     0.0388
#      ts_code  ann_date f_ann_date  end_date report_type comp_type  basic_eps
# 0  600225.SH  20191029   20191029  20190930           1         1      -0.35
# 1  600225.SH  20191029   20191029  20190930           1         1      -0.35
#      ts_code  ann_date f_ann_date  end_date report_type comp_type  basic_eps
# 0  600322.SH  20191030   20191030  20190930           1         1     0.1978
# 1  600322.SH  20191030   20191030  20190930           1         1     0.1978
# ...

# %%
print(data_sh_tj)
# Out:
#         ts_code  symbol  name area industry market list_date
# 62    600082.SH  600082  海泰发展   天津     园区开发     主板  19970620
# 128   600158.SH  600158  中体产业   天津     文教休闲     主板  19980327
# 187   600225.SH  600225  天津松江   天津     区域地产     主板  20000127
# 270   600322.SH  600322  天房发展   天津     区域地产     主板  20010910
# 276   600329.SH  600329  中新药业   天津      中成药     主板  20010606
# 281   600335.SH  600335  国机汽车   天津     汽车配件     主板  20010305
# 375   600468.SH  600468  百利电气   天津     电气设备     主板  20010615
# 390   600488.SH  600488  天药股份   天津     化学制药     主板  20010618
# 431   600535.SH  600535   天士力   天津      中成药     主板  20020823
# 472   600583.SH  600583  海油工程   天津     石油开采     主板  20020205
# 527   600645.SH  600645  中源协和   天津     生物制药     主板  19930504
# 590   600717.SH  600717   天津港   天津       港口     主板  19960614
# 623   600751.SH  600751  海航科技   天津       水运     主板  19960909
# 655   600787.SH  600787  中储股份   天津     仓储物流     主板  19970121
# ...

# %%
 ts_income = pro.income(ts_code='600322.SH', start_date='20190101', end_date='20190730')

# %%
print(ts_income)
# Out:
#      ts_code  ann_date f_ann_date  end_date report_type comp_type  basic_eps  \
# 0  600322.SH  20190427   20190427  20190331           1         1     0.1453
# 1  600322.SH  20190427   20190427  20181231           1         1     0.1218
# 2  600322.SH  20190427   20190427  20181231           1         1     0.1218
#
#    diluted_eps  total_revenue       revenue  ... minority_gain  \
# 0       0.1453   2.197599e+09  2.197599e+09  ...    1705910.51
# 1       0.1218   3.401414e+09  3.401414e+09  ...    9319117.38
# 2       0.1218   3.401414e+09  3.401414e+09  ...    9319117.38
#
#   oth_compr_income t_compr_income compr_inc_attr_p compr_inc_attr_m_s  \
# 0             None   1.623525e+08     1.606466e+08         1705910.51
# 1             None   1.440363e+08     1.347171e+08         9319117.38
# 2             None   1.440363e+08     1.347171e+08         9319117.38
#
#            ebit        ebitda insurance_exp undist_profit distable_profit
# ...

# %%
 ts_income = pro.income(ts_code='600322.SH', end_date='20191231')

# %%
print(ts_income)
# Out:
#       ts_code  ann_date f_ann_date  end_date report_type comp_type  basic_eps  \
# 0   600322.SH  20191030   20191030  20190930           1         1     0.1978
# 1   600322.SH  20191030   20191030  20190930           1         1     0.1978
# 2   600322.SH  20190824   20190824  20190630           1         1     0.2167
# 3   600322.SH  20190824   20190824  20190630           1         1     0.2167
# 4   600322.SH  20190427   20190427  20190331           1         1     0.1453
# ..        ...       ...        ...       ...         ...       ...        ...
# 74  600322.SH  20020328   20020328  20011231           1         1        NaN
# 75  600322.SH  20010905   20010905  20010630           1         1        NaN
# 76  600322.SH  20010731   20010731  20001231           1         1        NaN
# 77  600322.SH  20010731   20010731  19991231           1         1        NaN
# 78  600322.SH  20010731   20010731  19981231           1         1        NaN
#
# ...

# %%
ts_income[['ts_code','end_date', 'report_type', 'comp_type',  'basic_eps']]
# Out:
#       ts_code  end_date report_type comp_type  basic_eps
# 0   600322.SH  20190930           1         1     0.1978
# 1   600322.SH  20190930           1         1     0.1978
# 2   600322.SH  20190630           1         1     0.2167
# 3   600322.SH  20190630           1         1     0.2167
# 4   600322.SH  20190331           1         1     0.1453
# ..        ...       ...         ...       ...        ...
# 74  600322.SH  20011231           1         1        NaN
# 75  600322.SH  20010630           1         1        NaN
# 76  600322.SH  20001231           1         1        NaN
# 77  600322.SH  19991231           1         1        NaN
# 78  600322.SH  19981231           1         1        NaN
#
# [79 rows x 5 columns]

# %%
ts_income[['ts_code','end_date', 'report_type', 'comp_type',  'basic_eps']].filter['basic_eps' <> 'NaN']
# Out:
#   File "<ipython-input-62-c4ccbb1b45e1>", line 1
#     ts_income[['ts_code','end_date', 'report_type', 'comp_type',  'basic_eps']].filter['basic_eps' <> 'NaN']
#                                                                                                     ^
# SyntaxError: invalid syntax

# %%
ts_income[['ts_code','end_date', 'report_type', 'comp_type',  'basic_eps']].filter['basic_eps' is not 'NaN']
# Out:
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <ipython-input-63-73a526c7b024>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   ts_income[['ts_code','end_date', 'report_type', 'comp_type',  'basic_eps']].filter['basic_eps' is not 'NaN']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-73a526c7b024> in <module>
# ----> 1 ts_income[['ts_code','end_date', 'report_type', 'comp_type',  'basic_eps']].filter['basic_eps' is not 'NaN']
#
# TypeError: 'method' object is not subscriptable

# %%
ts_income[['ts_code','end_date', 'report_type', 'comp_type',  'basic_eps']].filter['basic_eps' is not None]
# Out:
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <ipython-input-64-5b1510887de5>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   ts_income[['ts_code','end_date', 'report_type', 'comp_type',  'basic_eps']].filter['basic_eps' is not None]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-5b1510887de5> in <module>
# ----> 1 ts_income[['ts_code','end_date', 'report_type', 'comp_type',  'basic_eps']].filter['basic_eps' is not None]
#
# TypeError: 'method' object is not subscriptable

# %%
ts_income[['ts_code','end_date', 'report_type', 'comp_type',  'basic_eps']].filter('basic_eps' is not None)
# Out:
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <ipython-input-65-e04ed897c5c7>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   ts_income[['ts_code','end_date', 'report_type', 'comp_type',  'basic_eps']].filter('basic_eps' is not None)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-e04ed897c5c7> in <module>
# ----> 1 ts_income[['ts_code','end_date', 'report_type', 'comp_type',  'basic_eps']].filter('basic_eps' is not None)
#
# ~/trading/invest_stock/venv/lib/python3.8/site-packages/pandas/core/generic.py in filter(self, items, like, regex, axis)
#    4697         if items is not None:
#    4698             name = self._get_axis_name(axis)
# -> 4699             return self.reindex(**{name: [r for r in items if r in labels]})
#    4700         elif like:
# ...

# %%
ts_income[['ts_code','end_date', 'report_type', 'comp_type',  'basic_eps']].filter('basic_eps' != None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-dbd3835ed6f1> in <module>
# ----> 1 ts_income[['ts_code','end_date', 'report_type', 'comp_type',  'basic_eps']].filter('basic_eps' != None)
#
# ~/trading/invest_stock/venv/lib/python3.8/site-packages/pandas/core/generic.py in filter(self, items, like, regex, axis)
#    4697         if items is not None:
#    4698             name = self._get_axis_name(axis)
# -> 4699             return self.reindex(**{name: [r for r in items if r in labels]})
#    4700         elif like:
#    4701
#
# TypeError: 'bool' object is not iterable

# %%
tf_clean=ts_income[['ts_code','end_date', 'report_type', 'comp_type',  'basic_eps']]

# %%
tf_clean[[tf_clean] is None]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/trading/invest_stock/venv/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-118e88fcd267> in <module>
# ...

# %%
tf_clean[tf_clean['basic_eps'] is None]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/trading/invest_stock/venv/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-69-4bf25a8dbab9> in <module>
# ...

# %%
tf_clean[tf_clean['basic_eps'] >0 ]
# Out:
#       ts_code  end_date report_type comp_type  basic_eps
# 0   600322.SH  20190930           1         1     0.1978
# 1   600322.SH  20190930           1         1     0.1978
# 2   600322.SH  20190630           1         1     0.2167
# 3   600322.SH  20190630           1         1     0.2167
# 4   600322.SH  20190331           1         1     0.1453
# 5   600322.SH  20181231           1         1     0.1218
# 6   600322.SH  20181231           1         1     0.1218
# 7   600322.SH  20180930           1         1     0.1345
# 8   600322.SH  20180630           1         1     0.1266
# 9   600322.SH  20180331           1         1     0.0677
# 10  600322.SH  20171231           1         1     0.1973
# 11  600322.SH  20170930           1         1     0.1600
# 12  600322.SH  20170630           1         1     0.1581
# 13  600322.SH  20170331           1         1     0.0493
# 17  600322.SH  20160331           1         1     0.0030
# ...

# %%
tf_income.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-edbfaa8102b3> in <module>
# ----> 1 tf_income.columns
#
# NameError: name 'tf_income' is not defined

# %%
ts_income.columns
# Out:
# Index(['ts_code', 'ann_date', 'f_ann_date', 'end_date', 'report_type',
#        'comp_type', 'basic_eps', 'diluted_eps', 'total_revenue', 'revenue',
#        'int_income', 'prem_earned', 'comm_income', 'n_commis_income',
#        'n_oth_income', 'n_oth_b_income', 'prem_income', 'out_prem',
#        'une_prem_reser', 'reins_income', 'n_sec_tb_income', 'n_sec_uw_income',
#        'n_asset_mg_income', 'oth_b_income', 'fv_value_chg_gain',
#        'invest_income', 'ass_invest_income', 'forex_gain', 'total_cogs',
#        'oper_cost', 'int_exp', 'comm_exp', 'biz_tax_surchg', 'sell_exp',
#        'admin_exp', 'fin_exp', 'assets_impair_loss', 'prem_refund',
#        'compens_payout', 'reser_insur_liab', 'div_payt', 'reins_exp',
#        'oper_exp', 'compens_payout_refu', 'insur_reser_refu',
#        'reins_cost_refund', 'other_bus_cost', 'operate_profit',
#        'non_oper_income', 'non_oper_exp', 'nca_disploss', 'total_profit',
# ...

# %%
tf_clean=ts_income[['ts_code','end_date', 'total_profit', 'income_tax']]

# %%
tf_clean
# Out:
#       ts_code  end_date  total_profit    income_tax
# 0   600322.SH  20190930  3.763157e+08  1.190971e+08
# 1   600322.SH  20190930  3.763157e+08  1.190971e+08
# 2   600322.SH  20190630  4.000871e+08  1.190256e+08
# 3   600322.SH  20190630  4.000871e+08  1.190256e+08
# 4   600322.SH  20190331  2.276666e+08  6.531411e+07
# ..        ...       ...           ...           ...
# 74  600322.SH  20011231  9.293648e+07  1.976378e+07
# 75  600322.SH  20010630  3.879901e+07  1.017283e+07
# 76  600322.SH  20001231  9.603416e+07  3.295349e+07
# 77  600322.SH  19991231  4.540865e+07  2.471712e+07
# 78  600322.SH  19981231  9.587102e+07  4.105990e+07
#
# [79 rows x 4 columns]

# %%
tf_clean=ts_income[['ts_code','end_date', 'total_profit', 'income_tax', 'n_income']]

# %%
tf_clean
# Out:
#       ts_code  end_date  total_profit    income_tax      n_income
# 0   600322.SH  20190930  3.763157e+08  1.190971e+08  2.572186e+08
# 1   600322.SH  20190930  3.763157e+08  1.190971e+08  2.572186e+08
# 2   600322.SH  20190630  4.000871e+08  1.190256e+08  2.810615e+08
# 3   600322.SH  20190630  4.000871e+08  1.190256e+08  2.810615e+08
# 4   600322.SH  20190331  2.276666e+08  6.531411e+07  1.623525e+08
# ..        ...       ...           ...           ...           ...
# 74  600322.SH  20011231  9.293648e+07  1.976378e+07  7.316837e+07
# 75  600322.SH  20010630  3.879901e+07  1.017283e+07  2.859549e+07
# 76  600322.SH  20001231  9.603416e+07  3.295349e+07  6.308067e+07
# 77  600322.SH  19991231  4.540865e+07  2.471712e+07  6.799631e+07
# 78  600322.SH  19981231  9.587102e+07  4.105990e+07  5.481112e+07
#
# [79 rows x 5 columns]

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
tf_clean
# Out:
#       ts_code  end_date    total_profit      income_tax        n_income
# 0   600322.SH  20190930 376315718.59000 119097073.89000 257218644.70000
# 1   600322.SH  20190930 376315718.59000 119097073.89000 257218644.70000
# 2   600322.SH  20190630 400087091.10000 119025570.42000 281061520.68000
# 3   600322.SH  20190630 400087091.10000 119025570.42000 281061520.68000
# 4   600322.SH  20190331 227666628.94000  65314110.87000 162352518.07000
# ..        ...       ...             ...             ...             ...
# 74  600322.SH  20011231  92936484.09000  19763784.46000  73168369.30000
# 75  600322.SH  20010630  38799014.08000  10172830.32000  28595491.12000
# 76  600322.SH  20001231  96034160.65000  32953487.13000  63080673.52000
# 77  600322.SH  19991231  45408648.83000  24717117.90000  67996313.31000
# 78  600322.SH  19981231  95871017.65000  41059900.69000  54811116.96000
#
# [79 rows x 5 columns]
